# %% [markdown]
# # **Load Libraries**

# %%
#used to reload block diagrams
import numpy as np                    #for multi-dimentional containters
import pandas as pd                   #for dataframes
import plotly.graph_objects as go     #for data visualization
import random
import copy
import matplotlib.pyplot as plt

# %% [markdown]
# # **How does Genetic Algorithm Work?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Number of individuals in each generation
POPULATION_SIZE = 100

# Valid genes
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

# Target string to be generated
TARGET = "SPHERE!"

class Individual(object):
	'''
	Class representing individual in population
	'''
	def __init__(self, chromosome):
		self.chromosome = chromosome
		self.fitness = self.cal_fitness()

	@classmethod
	def mutated_genes(self):
		'''
		create random genes for mutation
		'''
		global GENES
		gene = random.choice(GENES)
		return gene

	@classmethod
	def create_gnome(self):
		'''
		create chromosome or string of genes
		'''
		global TARGET
		gnome_len = len(TARGET)
		return [self.mutated_genes() for _ in range(gnome_len)]

	def mate(self, par2):
		'''
		Perform mating and produce new offspring
		'''

		# chromosome for offspring
		child_chromosome = []
		for gp1, gp2 in zip(self.chromosome, par2.chromosome):

			# random probability
			prob = random.random()

			# if prob is less than 0.45, insert gene
			# from parent 1
			if prob < 0.45:
				child_chromosome.append(gp1)

			# if prob is between 0.45 and 0.90, insert
			# gene from parent 2
			elif prob < 0.90:
				child_chromosome.append(gp2)

			# otherwise insert random gene(mutate),
			# for maintaining diversity
			else:
				child_chromosome.append(self.mutated_genes())

		# create new Individual(offspring) using
		# generated chromosome for offspring
		return Individual(child_chromosome)

	def cal_fitness(self):
		'''
		Calculate fitness score, it is the number of
		characters in string which differ from target
		string.
		'''
		global TARGET
		fitness = 0
		for gs, gt in zip(self.chromosome, TARGET):
			if gs != gt: fitness+= 1
		return fitness

# Driver code
def main():
	global POPULATION_SIZE

	#current generation
	generation = 1

	found = False
	population = []

	# create initial population
	for _ in range(POPULATION_SIZE):
				gnome = Individual.create_gnome()
				population.append(Individual(gnome))

	while not found:

		# sort the population in increasing order of fitness score
		population = sorted(population, key = lambda x:x.fitness)

		# if the individual having lowest fitness score ie.
		# 0 then we know that we have reached to the target
		# and break the loop
		if population[0].fitness <= 0:
			found = True
			break

		# Otherwise generate new offsprings for new generation
		new_generation = []

		# Perform Elitism, that mean 10% of fittest population
		# goes to the next generation
		s = int((10*POPULATION_SIZE)/100)
		new_generation.extend(population[:s])

		# From 50% of fittest population, Individuals
		# will mate to produce offspring
		s = int((90*POPULATION_SIZE)/100)
		for _ in range(s):
			parent1 = random.choice(population[:50])
			parent2 = random.choice(population[:50])
			child = parent1.mate(parent2)
			new_generation.append(child)

		population = new_generation

		print("Generation: {}\tString: {}\tFitness: {}".\
			format(generation,
			"".join(population[0].chromosome),
			population[0].fitness))

		generation += 1


	print("Generation: {}\tString: {}\tFitness: {}".\
		format(generation,
		"".join(population[0].chromosome),
		population[0].fitness))

if __name__ == '__main__':
	main()
# Out:
# Generation: 1	String: w}xasE"	Fitness: 6
# Generation: 2	String: w}xasE"	Fitness: 6
# Generation: 3	String: @E}?RE 	Fitness: 5
# Generation: 4	String: @E}?RE 	Fitness: 5
# Generation: 5	String: @E}?RE 	Fitness: 5
# Generation: 6	String: SGHaRE"	Fitness: 3
# Generation: 7	String: SGHaRE"	Fitness: 3
# Generation: 8	String: SGHaRE"	Fitness: 3
# Generation: 9	String: SGHaRE"	Fitness: 3
# Generation: 10	String: SGHaRE"	Fitness: 3
# Generation: 11	String: SDHVRE!	Fitness: 2
# Generation: 12	String: SDHVRE!	Fitness: 2
# Generation: 13	String: SDHVRE!	Fitness: 2
# Generation: 14	String: SEHERE!	Fitness: 1
# Generation: 15	String: SEHERE!	Fitness: 1
# Generation: 16	String: SEHERE!	Fitness: 1
# Generation: 17	String: SEHERE!	Fitness: 1
# Generation: 18	String: SEHERE!	Fitness: 1
# Generation: 19	String: SEHERE!	Fitness: 1
# Generation: 20	String: SEHERE!	Fitness: 1
# Generation: 21	String: SEHERE!	Fitness: 1
# Generation: 22	String: SEHERE!	Fitness: 1
# Generation: 23	String: SEHERE!	Fitness: 1
# Generation: 24	String: SEHERE!	Fitness: 1
# Generation: 25	String: SEHERE!	Fitness: 1
# Generation: 26	String: SEHERE!	Fitness: 1
# Generation: 27	String: SEHERE!	Fitness: 1
# Generation: 28	String: SEHERE!	Fitness: 1
# Generation: 29	String: SEHERE!	Fitness: 1
# Generation: 30	String: SEHERE!	Fitness: 1
# Generation: 31	String: SEHERE!	Fitness: 1
# Generation: 32	String: SEHERE!	Fitness: 1
# Generation: 33	String: SEHERE!	Fitness: 1
# Generation: 34	String: SEHERE!	Fitness: 1
# Generation: 35	String: SEHERE!	Fitness: 1
# Generation: 36	String: SEHERE!	Fitness: 1
# Generation: 37	String: SEHERE!	Fitness: 1
# Generation: 38	String: SEHERE!	Fitness: 1
# Generation: 39	String: SEHERE!	Fitness: 1
# Generation: 40	String: SEHERE!	Fitness: 1
# Generation: 41	String: SPHERE!	Fitness: 0

# %% [markdown]
# # **Let's optimize to sphere function.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Input Domain:**
#
# # The function is usually evaluated on the hypercube xi ∈ [-5.12, 5.12], for all i = 1, …, d.

# %% [markdown]
# # **Global Minimum:**

# %% [markdown]
# ![spheref3.png](data:image/png;base64,...)

# %% [markdown]
# #**Implement Genetic Algorithm**

# %% [markdown]
# ##Define the sphere function

# %%
# cost function
def sphere(x):
    return sum(x**2)

# %% [markdown]
# # **Parent selection techniques**

# %% [markdown]
# #**1) Roulette wheel selection:**

# %%
def roulette_wheel_selection(p):
    c = np.cumsum(p)
    r = sum(p) * np.random.rand()
    ind = np.argwhere(r <= c)
    return ind[0][0]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**2) Tournment selection:**

# %% [markdown]
# ![Binary-tournament-selection.png](data:image/png;base64,...)

# %%
def tournament_selection(population, k):
    indices = np.random.choice(len(population), k, replace=False)
    return min(indices, key=lambda i: population[i]['cost'])

# %% [markdown]
# # **Recombination techniques**

# %% [markdown]
# #**1) Uniform Crossover**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def uniform_crossover(p1, p2):
    c1 = copy.deepcopy(p1)
    c2 = copy.deepcopy(p2)
    alpha = np.random.uniform(0, 1, c1['position'].shape)
    c1['position'] = alpha * p1['position'] + (1 - alpha) * p2['position']
    c2['position'] = alpha * p2['position'] + (1 - alpha) * p1['position']
    return c1, c2

# %% [markdown]
# # **2) Single-point crossover**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def single_point_crossover(p1, p2):
    c1 = copy.deepcopy(p1)
    c2 = copy.deepcopy(p2)
    point = np.random.randint(1, len(c1['position']) - 1)
    c1['position'][:point] = p1['position'][:point]
    c1['position'][point:] = p2['position'][point:]
    c2['position'][:point] = p2['position'][:point]
    c2['position'][point:] = p1['position'][point:]
    return c1, c2

# %% [markdown]
# # **Mutation techniques**

# %% [markdown]
# # **1) Gaussian mutation**

# %% [markdown]
# ![Gaussian-mutation-operation.png](data:image/png;base64,...)

# %%
def gaussian_mutation(c, mu, sigma):
    y = copy.deepcopy(c)
    flag = np.random.rand(*c['position'].shape) <= mu
    ind = np.argwhere(flag)
    y['position'][ind] += sigma * np.random.randn(*ind.shape)
    return y

# %% [markdown]
# # **2) Uniform Mutation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def uniform_mutation(c, mu, sigma):
    y = copy.deepcopy(c)
    for i in range(len(c['position'])):
        if np.random.rand() <= mu:
            y['position'][i] += sigma * np.random.randn()
    return y

# %% [markdown]
# # **Bounds function**

# %%
def bounds(c, varmin, varmax):
    c['position'] = np.maximum(c['position'], varmin)
    c['position'] = np.minimum(c['position'], varmax)
    return c['position']

# %% [markdown]
# # **Sorting function**

# %%
def sort(arr):
    n = len(arr)
    for i in range(n - 1):
        for j in range(0, n - i - 1):
            if arr[j]['cost'] > arr[j + 1]['cost']:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

# %% [markdown]
# # **Representation 1: Binary Representation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def binary_representation(num_var, npop):
    population = [{'position': np.random.randint(2, size=num_var), 'cost': None} for _ in range(npop)]
    return population

# %% [markdown]
# #**Representation 2: Real-Valued Representation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def real_valued_representation(num_var, varmin, varmax, npop):
    population = [{'position': np.random.uniform(varmin, varmax, num_var), 'cost': None} for _ in range(npop)]
    return population

# %% [markdown]
# #**RUN GA**

# %%
def ga(costfunc, num_var, varmin, varmax, maxit, npop, num_children, mu, sigma, tournament_size, verbose, parent_selection, crossover, mutation):
    # Initialize population
    population = binary_representation(num_var, npop)  # Change to real_valued_representation for real-valued representation

    # Evaluate initial population
    for ind in population:
        ind['cost'] = costfunc(ind['position'])

    # Best solution found
    bestsol = min(population, key=lambda x: x['cost'])

    # Best cost of each generation
    bestcost = np.empty(maxit)

    # Main loop
    for it in range(maxit):
        # Generate offsprings
        offsprings = []
        for _ in range(num_children // 2):
            # Parent selection
            if parent_selection == "RouletteWheel":
                p1 = population[roulette_wheel_selection([ind['cost'] for ind in population])]
                p2 = population[roulette_wheel_selection([ind['cost'] for ind in population])]
            elif parent_selection == "Tournament":
                p1 = population[tournament_selection(population, tournament_size)]
                p2 = population[tournament_selection(population, tournament_size)]

            # Recombination
            if crossover == "Uniform":
                c1, c2 = uniform_crossover(p1, p2)
            elif crossover == "SinglePoint":
                c1, c2 = single_point_crossover(p1, p2)

            # Mutation
            if mutation == "Gaussian":
                c1 = gaussian_mutation(c1, mu, sigma)
                c2 = gaussian_mutation(c2, mu, sigma)
            elif mutation == "Uniform":
                c1 = uniform_mutation(c1, mu, sigma)

            # Apply bounds
            c1['position'] = bounds(c1, varmin, varmax)
            c2['position'] = bounds(c2, varmin, varmax)

            # Evaluate offsprings
            c1['cost'] = costfunc(c1['position'])
            c2['cost'] = costfunc(c2['position'])

            offsprings.extend([c1, c2])

        # Merge, Sort and Select
        population.extend(offsprings)
        population = sort(population)
        population = population[:npop]

        # Update best solution
        if c1['cost'] < bestsol['cost']:
            bestsol = copy.deepcopy(c1)
        if c2['cost'] < bestsol['cost']:
            bestsol = copy.deepcopy(c2)

        # Replace worst individuals in population
        population.append(c1)
        population.append(c2)

        # Evaluate new population
        for ind in population:
            if ind['cost'] is None:
                ind['cost'] = costfunc(ind['position'])

        # Remove individuals with None cost
        population = [ind for ind in population if ind['cost'] is not None]

        # Sort population
        population = sorted(population, key=lambda x: x['cost'])[:npop]

        # Store best cost
        bestcost[it] = bestsol['cost']

        # Show generation information
        if verbose and it % verbose == 0:
            print('Iteration {}: Best Cost = {}'.format(it, bestcost[it]))

    return population, bestsol, bestcost

# %%
# Problem definition
costfunc = sphere
num_var = 5
varmin = -5.12
varmax = 5.12

# GA Parameters
maxit = 500
npop = 20
beta = 1
prop_children = 4
num_children = int(np.round(prop_children * npop / 2) * 2)
mu = 0.2
sigma = 0.2
verbose = 100
tournament_size = 5  # Define tournament size

# %% [markdown]
# #**Visualize and compare the results**

# %% [markdown]
# # **Binary Representation VS. Real-Valued Representation**

# %% [markdown]
# # **1) Binary Representation**

# %% [markdown]
# # **Uniform Crossover VS. Single-Point Crossover**

# %%
# Run GA for the specific combination
parent_selection = "RouletteWheel"  # Change to "RouletteWheel" if needed
crossover = "Uniform"
mutation = "gaussian"
print("Parent Selection:", parent_selection)
print("Crossover:", crossover)
print("Mutation:", mutation)
out = ga(costfunc, num_var, varmin, varmax, maxit, npop, num_children, mu, sigma, tournament_size, verbose,
         parent_selection=parent_selection, crossover=crossover, mutation=mutation)
plt.plot(out[2], label=f"{parent_selection}-{crossover}-{mutation}")
plt.xlabel('Generations')
plt.ylabel('Best Cost')
plt.title('Genetic Algorithm')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Parent Selection: RouletteWheel
# Crossover: Uniform
# Mutation: gaussian
# Iteration 0: Best Cost = 2.0
# Iteration 100: Best Cost = 0.11017949992612325
# Iteration 200: Best Cost = 0.11017949992612323
# Iteration 300: Best Cost = 0.11017949992612323
# Iteration 400: Best Cost = 0.11017949992612323

# %%
# Run GA for the specific combination
parent_selection = "RouletteWheel"
crossover = "SinglePoint"
mutation = "gaussian"
print("Parent Selection:", parent_selection)
print("Crossover:", crossover)
print("Mutation:", mutation)
out = ga(costfunc, num_var, varmin, varmax, maxit, npop, num_children, mu, sigma, tournament_size, verbose,
         parent_selection=parent_selection, crossover=crossover, mutation=mutation)
plt.plot(out[2], label=f"{parent_selection}-{crossover}-{mutation}")
plt.xlabel('Generations')
plt.ylabel('Best Cost')
plt.title('Genetic Algorithm')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Parent Selection: RouletteWheel
# Crossover: SinglePoint
# Mutation: gaussian
# Iteration 0: Best Cost = 1.0
# Iteration 100: Best Cost = 0.0
# Iteration 200: Best Cost = 0.0
# Iteration 300: Best Cost = 0.0
# Iteration 400: Best Cost = 0.0

# %% [markdown]
# # **Gaussian Mutation VS. Uniform Mutation**

# %%
# Run GA for the specific combination
parent_selection = "RouletteWheel"
crossover = "Uniform"
mutation = "gaussian"
print("Parent Selection:", parent_selection)
print("Crossover:", crossover)
print("Mutation:", mutation)
out = ga(costfunc, num_var, varmin, varmax, maxit, npop, num_children, mu, sigma, tournament_size, verbose,
         parent_selection=parent_selection, crossover=crossover, mutation=mutation)
plt.plot(out[2], label=f"{parent_selection}-{crossover}-{mutation}")
plt.xlabel('Generations')
plt.ylabel('Best Cost')
plt.title('Genetic Algorithm')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Parent Selection: RouletteWheel
# Crossover: Uniform
# Mutation: gaussian
# Iteration 0: Best Cost = 0.0
# Iteration 100: Best Cost = 0.0
# Iteration 200: Best Cost = 0.0
# Iteration 300: Best Cost = 0.0
# Iteration 400: Best Cost = 0.0

# %%
# Run GA for the specific combination
parent_selection = "RouletteWheel"  # Change to "RouletteWheel" if needed
crossover = "Uniform"
mutation = "Uniform"
print("Parent Selection:", parent_selection)
print("Crossover:", crossover)
print("Mutation:", mutation)
out = ga(costfunc, num_var, varmin, varmax, maxit, npop, num_children, mu, sigma, tournament_size, verbose,
         parent_selection=parent_selection, crossover=crossover, mutation=mutation)
plt.plot(out[2], label=f"{parent_selection}-{crossover}-{mutation}")
plt.xlabel('Generations')
plt.ylabel('Best Cost')
plt.title('Genetic Algorithm')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Parent Selection: RouletteWheel
# Crossover: Uniform
# Mutation: Uniform
# Iteration 0: Best Cost = 1.0
# Iteration 100: Best Cost = 4.5258999246738455e-06
# Iteration 200: Best Cost = 3.5410780815964074e-09
# Iteration 300: Best Cost = 2.127632066696224e-09
# Iteration 400: Best Cost = 2.127632066696224e-09

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **2) Real valued Representation**

# %%
def ga(costfunc, num_var, varmin, varmax, maxit, npop, num_children, mu, sigma, tournament_size, verbose, parent_selection, crossover, mutation):
    # Initialize population
    population = real_valued_representation(num_var, varmin, varmax, npop)  # Change to real_valued_representation for real-valued representation

    # Evaluate initial population
    for ind in population:
        ind['cost'] = costfunc(ind['position'])

    # Best solution found
    bestsol = min(population, key=lambda x: x['cost'])

    # Best cost of each generation
    bestcost = np.empty(maxit)

    # Main loop
    for it in range(maxit):
        # Generate offsprings
        offsprings = []
        for _ in range(num_children // 2):
            # Parent selection
            if parent_selection == "RouletteWheel":
                p1 = population[roulette_wheel_selection([ind['cost'] for ind in population])]
                p2 = population[roulette_wheel_selection([ind['cost'] for ind in population])]
            elif parent_selection == "Tournament":
                p1 = population[tournament_selection(population, tournament_size)]
                p2 = population[tournament_selection(population, tournament_size)]

            # Recombination
            if crossover == "Uniform":
                c1, c2 = uniform_crossover(p1, p2)
            elif crossover == "SinglePoint":
                c1, c2 = single_point_crossover(p1, p2)

            # Mutation
            if mutation == "Gaussian":
                c1 = gaussian_mutation(c1, mu, sigma)
                c2 = gaussian_mutation(c2, mu, sigma)
            elif mutation == "Uniform":
                c1 = uniform_mutation(c1, mu, sigma)

            # Apply bounds
            c1['position'] = bounds(c1, varmin, varmax)
            c2['position'] = bounds(c2, varmin, varmax)

            # Evaluate offsprings
            c1['cost'] = costfunc(c1['position'])
            c2['cost'] = costfunc(c2['position'])

            offsprings.extend([c1, c2])

        # Merge, Sort and Select
        population.extend(offsprings)
        population = sort(population)
        population = population[:npop]

        # Update best solution
        if c1['cost'] < bestsol['cost']:
            bestsol = copy.deepcopy(c1)
        if c2['cost'] < bestsol['cost']:
            bestsol = copy.deepcopy(c2)

        # Replace worst individuals in population
        population.append(c1)
        population.append(c2)

        # Evaluate new population
        for ind in population:
            if ind['cost'] is None:
                ind['cost'] = costfunc(ind['position'])

        # Remove individuals with None cost
        population = [ind for ind in population if ind['cost'] is not None]

        # Sort population
        population = sorted(population, key=lambda x: x['cost'])[:npop]

        # Store best cost
        bestcost[it] = bestsol['cost']

        # Show generation information
        if verbose and it % verbose == 0:
            print('Iteration {}: Best Cost = {}'.format(it, bestcost[it]))

    return population, bestsol, bestcost

# %%
# Run GA for the specific combination
parent_selection = "RouletteWheel"
crossover = "Uniform"
mutation = "gaussian"
print("Parent Selection:", parent_selection)
print("Crossover:", crossover)
print("Mutation:", mutation)
out = ga(costfunc, num_var, varmin, varmax, maxit, npop, num_children, mu, sigma, tournament_size, verbose,
         parent_selection=parent_selection, crossover=crossover, mutation=mutation)
plt.plot(out[2], label=f"{parent_selection}-{crossover}-{mutation}")
plt.xlabel('Generations')
plt.ylabel('Best Cost')
plt.title('Genetic Algorithm')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Parent Selection: RouletteWheel
# Crossover: Uniform
# Mutation: gaussian
# Iteration 0: Best Cost = 6.368707723175702
# Iteration 100: Best Cost = 0.00017397888936867444
# Iteration 200: Best Cost = 0.00017397888936867444
# Iteration 300: Best Cost = 0.00017397888936867444
# Iteration 400: Best Cost = 0.00017397888936867444

# %%
# Run GA for the specific combination
parent_selection = "RouletteWheel"  # Change to "RouletteWheel" if needed
crossover = "Uniform"
mutation = "Uniform"
print("Parent Selection:", parent_selection)
print("Crossover:", crossover)
print("Mutation:", mutation)
out = ga(costfunc, num_var, varmin, varmax, maxit, npop, num_children, mu, sigma, tournament_size, verbose,
         parent_selection=parent_selection, crossover=crossover, mutation=mutation)
plt.plot(out[2], label=f"{parent_selection}-{crossover}-{mutation}")
plt.xlabel('Generations')
plt.ylabel('Best Cost')
plt.title('Genetic Algorithm')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Parent Selection: RouletteWheel
# Crossover: Uniform
# Mutation: Uniform
# Iteration 0: Best Cost = 21.318437391460026
# Iteration 100: Best Cost = 6.199171136129935e-07
# Iteration 200: Best Cost = 1.6443579519425695e-07
# Iteration 300: Best Cost = 1.6443579519425695e-07
# Iteration 400: Best Cost = 4.575071556046943e-08

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import numpy as np
import copy

# %%
# Create the main application window
app = tk.Tk()
app.title("Genetic Algorithm Demo")

# Function to run the Genetic Algorithm based on user inputs
def run_genetic_algorithm():
    # Fetch user inputs
    num_var = int(entry_num_var.get())
    varmin = float(entry_varmin.get())
    varmax = float(entry_varmax.get())
    maxit = int(entry_maxit.get())
    npop = int(entry_npop.get())
    mu = float(entry_mu.get())
    sigma = float(entry_sigma.get())
    parent_selection = combo_parent_selection.get()
    crossover = combo_crossover.get()
    mutation = combo_mutation.get()

    # Run the Genetic Algorithm
    out = ga(costfunc, num_var, varmin, varmax, maxit, npop, num_children, mu, sigma, tournament_size, verbose,
             parent_selection=parent_selection, crossover=crossover, mutation=mutation)

    # Plot the results
    plot_results(out[2])

# Function to plot the results
def plot_results(bestcost):
    fig = Figure(figsize=(5, 4), dpi=100)
    plot = fig.add_subplot(1, 1, 1)
    plot.plot(bestcost)
    plot.set_xlabel('Generations')
    plot.set_ylabel('Best Cost')
    plot.set_title('Genetic Algorithm')
    plot.grid(True)

    canvas = FigureCanvasTkAgg(fig, master=app)
    canvas.draw()
    canvas.get_tk_widget().grid(row=12, columnspan=4)

# Add widgets for user input
# Number of variables
label_num_var = ttk.Label(app, text="Number of Variables:")
label_num_var.grid(row=0, column=0)
entry_num_var = ttk.Entry(app)
entry_num_var.grid(row=0, column=1)

# Variable minimum
label_varmin = ttk.Label(app, text="Variable Min:")
label_varmin.grid(row=1, column=0)
entry_varmin = ttk.Entry(app)
entry_varmin.grid(row=1, column=1)

# Variable maximum
label_varmax = ttk.Label(app, text="Variable Max:")
label_varmax.grid(row=2, column=0)
entry_varmax = ttk.Entry(app)
entry_varmax.grid(row=2, column=1)

# Maximum iterations
label_maxit = ttk.Label(app, text="Max Iterations:")
label_maxit.grid(row=3, column=0)
entry_maxit = ttk.Entry(app)
entry_maxit.grid(row=3, column=1)

# Population size
label_npop = ttk.Label(app, text="Population Size:")
label_npop.grid(row=4, column=0)
entry_npop = ttk.Entry(app)
entry_npop.grid(row=4, column=1)

# Mutation rate (mu)
label_mu = ttk.Label(app, text="Mutation Rate (mu):")
label_mu.grid(row=5, column=0)
entry_mu = ttk.Entry(app)
entry_mu.grid(row=5, column=1)

# Mutation standard deviation (sigma)
label_sigma = ttk.Label(app, text="Mutation Std Dev (sigma):")
label_sigma.grid(row=6, column=0)
entry_sigma = ttk.Entry(app)
entry_sigma.grid(row=6, column=1)

# Parent selection method
label_parent_selection = ttk.Label(app, text="Parent Selection:")
label_parent_selection.grid(row=7, column=0)
combo_parent_selection = ttk.Combobox(app, values=["RouletteWheel", "Tournament"])
combo_parent_selection.grid(row=7, column=1)
combo_parent_selection.current(0)

# Crossover method
label_crossover = ttk.Label(app, text="Crossover:")
label_crossover.grid(row=8, column=0)
combo_crossover = ttk.Combobox(app, values=["Uniform", "SinglePoint"])
combo_crossover.grid(row=8, column=1)
combo_crossover.current(0)

# Mutation method
label_mutation = ttk.Label(app, text="Mutation:")
label_mutation.grid(row=9, column=0)
combo_mutation = ttk.Combobox(app, values=["Gaussian", "Uniform"])
combo_mutation.grid(row=9, column=1)
combo_mutation.current(0)

# Run button
btn_run = ttk.Button(app, text="Run Genetic Algorithm", command=run_genetic_algorithm)
btn_run.grid(row=10, columnspan=2, pady=10)

# Main loop
app.mainloop()
# Out:
# Iteration 0: Best Cost = 3.610022024457125
# Iteration 100: Best Cost = 0.0011254998707474024
# Iteration 200: Best Cost = 1.2655342453721566e-05
# Iteration 300: Best Cost = 3.4762334692909165e-07
# Iteration 400: Best Cost = 4.6684574734699644e-08
